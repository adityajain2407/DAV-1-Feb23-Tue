# %% [markdown]
# <a href="https://colab.research.google.com/github/adityajain2407/DAV-1-Feb23-Tue/blob/main/07_pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2023-07-08 01:28:49--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 172.253.63.113, 172.253.63.102, 172.253.63.100, ...
# Connecting to drive.google.com (drive.google.com)|172.253.63.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/rkgbr3ak51hm4fd2vgf6hrlka5rak984/1688779725000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=11871e21-6b05-4218-acb7-f7d7f89de98d [following]
# ...
# --2023-07-08 01:28:50--  https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/rkgbr3ak51hm4fd2vgf6hrlka5rak984/1688779725000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=11871e21-6b05-4218-acb7-f7d7f89de98d
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.loc[len(df.index)] = ['India',2000,13500000,"asia",37.08,900.23]
df.loc[len(df.index)] = ['Sri Lanka',2022 ,130000000,"asia",80.00,500.00]
df.loc[len(df.index)] = ['Sri Lanka',2022 ,130000000,"asia",80.00,500.00]
df.loc[len(df.index)] = ['India',2000 ,13500000,"asia",80.00,900.23]
df.tail(10)
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 1698   Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699   Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700   Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701   Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704      India  2000    13500000      asia    37.080  900.230000
# 1705  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1706  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707      India  2000    13500000      asia    80.000  900.230000

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1703    False
# 1704    False
# 1705    False
# 1706     True
# 1707    False
# Length: 1708, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
#         country  year  population continent  life_exp  gdp_cap
# 1706  Sri Lanka  2022   130000000      asia      80.0    500.0

# %%
df.drop_duplicates()
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      asia    37.080  900.230000
# 1705    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707        India  2000    13500000      asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
df.tail()
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 1703   Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704      India  2000    13500000      asia    37.080  900.230000
# 1705  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1706  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707      India  2000    13500000      asia    80.000  900.230000

# %%
df.drop_duplicates(keep = "first")
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      asia    37.080  900.230000
# 1705    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707        India  2000    13500000      asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
df.drop_duplicates(keep = "last")
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      asia    37.080  900.230000
# 1706    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707        India  2000    13500000      asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
#fresh

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.loc[1:4]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[1:4]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138

# %%
df.iloc[1:5, 1:4]
# Out:
#    year  population continent
# 1  1957     9240934      Asia
# 2  1962    10267083      Asia
# 3  1967    11537966      Asia
# 4  1972    13079460      Asia

# %%
df.loc[1:5, 1:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-494208dc7680> in <cell line: 1>()
# ----> 1 df.loc[1:5, 1:4]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %%
df.loc[1:5, ["country", "life_exp"]]
# Out:
#        country  life_exp
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088
# 5  Afghanistan    38.438

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.loc[1:5, "year" : "continent"]
# Out:
#    year  population continent
# 1  1957     9240934      Asia
# 2  1962    10267083      Asia
# 3  1967    11537966      Asia
# 4  1972    13079460      Asia
# 5  1977    14880372      Asia

# %%
df.iloc[1:5, "year" : "continent"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-b43cb8a38c45> in <cell line: 1>()
# ----> 1 df.iloc[1:5, "year" : "continent"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1565             return self._getitem_lowerdim(tup)
#    1566
# -> 1567         return self._getitem_tuple_same_dim(tup)
#    1568
#    1569     def _get_list_axis(self, key, axis: int):
#
# ...

# %%
df.head(20)
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
df.iloc[ [0,10, 20, 100] , [0, 2, 3] ]
# Out:
#          country  population continent
# 0    Afghanistan     8425333      Asia
# 10   Afghanistan    25268405      Asia
# 20       Albania     3326498    Europe
# 100   Bangladesh    70759295      Asia

# %%
df.iloc[1:10:2]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.loc[1:10:2]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
le = df["life_exp"]
print(le)
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
le.mean()
# Out:
# 59.474439366197174

# %%
le.sum()
# Out:
# 101344.44467999999

# %%
le.count()
# Out:
# 1704

# %%
le.sum()/le.count()
# Out:
# 59.474439366197174

# %%
df.sort_values(['life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
df.sort_values(['life_exp'], ascending = False)
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# ...                ...   ...         ...       ...       ...           ...
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
#
# [1704 rows x 6 columns]

# %%
df.sort_values(['year', 'life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 1032        Mozambique  1952     6446316    Africa    31.286    468.526038
# ...                ...   ...         ...       ...       ...           ...
# 71           Australia  2007    20434176   Oceania    81.235  34435.367440
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1704 rows x 6 columns]

# %%
df.sort_values(['year', 'life_exp'], ascending = [True, False])
# Out:
#            country  year  population continent  life_exp       gdp_cap
# 1140        Norway  1952     3327728    Europe    72.670  10095.421720
# 684        Iceland  1952      147962    Europe    72.490   7267.688428
# 1080   Netherlands  1952    10381988    Europe    72.130   8941.571858
# 1464        Sweden  1952     7124673    Europe    71.860   8527.844662
# 408        Denmark  1952     4334000    Europe    70.780   9692.385245
# ...            ...   ...         ...       ...       ...           ...
# 887        Lesotho  2007     2012649    Africa    42.592   1569.331442
# 1355  Sierra Leone  2007     6144562    Africa    42.568    862.540756
# 1691        Zambia  2007    11746035    Africa    42.384   1271.211593
# 1043    Mozambique  2007    19951656    Africa    42.082    823.685621
# 1463     Swaziland  2007     1133066    Africa    39.613   4513.480643
#
# [1704 rows x 6 columns]

# %%
users = pd.DataFrame({"userid":[1, 2, 3], "name":["AJ", "Manoj", "Mukesh"]})
users
# Out:
#    userid    name
# 0       1      AJ
# 1       2   Manoj
# 2       3  Mukesh

# %%
msgs = pd.DataFrame({"userid":[1, 1, 2, 4], "msg":['hmm', "acha", "theek hai", "nice"]})
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
pd.concat([users, msgs], axis = 0)
# Out:
#    userid    name        msg
# 0       1      AJ        NaN
# 1       2   Manoj        NaN
# 2       3  Mukesh        NaN
# 0       1     NaN        hmm
# 1       1     NaN       acha
# 2       2     NaN  theek hai
# 3       4     NaN       nice

# %%
pd.concat([users, msgs], axis = 0, ignore_index = True)
# Out:
#    userid    name        msg
# 0       1      AJ        NaN
# 1       2   Manoj        NaN
# 2       3  Mukesh        NaN
# 3       1     NaN        hmm
# 4       1     NaN       acha
# 5       2     NaN  theek hai
# 6       4     NaN       nice

# %%
pd.concat([users, msgs], axis = 1)
# Out:
#    userid    name  userid        msg
# 0     1.0      AJ       1        hmm
# 1     2.0   Manoj       1       acha
# 2     3.0  Mukesh       2  theek hai
# 3     NaN     NaN       4       nice

# %%
users
# Out:
#    userid    name
# 0       1      AJ
# 1       2   Manoj
# 2       3  Mukesh

# %%
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
users.merge(msgs, on = "userid")
# Out:
#    userid   name        msg
# 0       1     AJ        hmm
# 1       1     AJ       acha
# 2       2  Manoj  theek hai

# %%
users.merge(msgs, on = "userid" , how = "outer")
# Out:
#    userid    name        msg
# 0       1      AJ        hmm
# 1       1      AJ       acha
# 2       2   Manoj  theek hai
# 3       3  Mukesh        NaN
# 4       4     NaN       nice

# %%
users.merge(msgs, on = "userid", how = "left")
# Out:
#    userid    name        msg
# 0       1      AJ        hmm
# 1       1      AJ       acha
# 2       2   Manoj  theek hai
# 3       3  Mukesh        NaN

# %%
users.merge(msgs, on ="userid", how = "right")
# Out:
#    userid   name        msg
# 0       1     AJ        hmm
# 1       1     AJ       acha
# 2       2  Manoj  theek hai
# 3       4    NaN       nice

# %%
users.rename(columns = {"userid" : "id"} , inplace = True)

# %%
users
# Out:
#    id    name
# 0   1      AJ
# 1   2   Manoj
# 2   3  Mukesh

# %%
users.merge(msgs, left_on = "id", right_on = "userid")
# Out:
#    id   name  userid        msg
# 0   1     AJ       1        hmm
# 1   1     AJ       1       acha
# 2   2  Manoj       2  theek hai

# %%
import numpy as np
import pandas as pd

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 24.6MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 87.0MB/s]

# %%
movies = pd.read_csv("movies.csv")
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
movies.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
#another way

# movies = pd.read_csv('movies.csv', index_col=0)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
movies.shape
# Out:
# (1465, 11)

# %%
directors = pd.read_csv('directors.csv', index_col=0)

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
directors.shape
# Out:
# (2349, 3)

# %%
movies["director_id"].value_counts()
# Out:
# 4799    26
# 4809    19
# 5087    19
# 5457    18
# 4779    16
#         ..
# 5105     5
# 4849     5
# 5096     5
# 5088     5
# 6204     5
# Name: director_id, Length: 199, dtype: int64

# %%
movies["director_id"].nunique()
# Out:
# 199

# %%
movies.shape
# Out:
# (1465, 11)

# %%
directors.shape
# Out:
# (2349, 3)

# %%
#among the directors present in movies df, how many are present in directors df

# %%
movies["director_id"]
# Out:
# 0       4762
# 1       4763
# 2       4764
# 3       4765
# 4       4767
#         ...
# 1460    4809
# 1461    5369
# 1462    5148
# 1463    5535
# 1464    5097
# Name: director_id, Length: 1465, dtype: int64

# %%
movies["director_id"].isin(directors["id"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1460    True
# 1461    True
# 1462    True
# 1463    True
# 1464    True
# Name: director_id, Length: 1465, dtype: bool

# %%
np.all(movies["director_id"].isin(directors["id"]))
# Out:
# True

# %%
movies.head(2)
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday

# %%
directors.head(2)
# Out:
#     director_name    id gender
# 0   James Cameron  4762   Male
# 1  Gore Verbinski  4763   Male

# %%
data = movies.merge(directors, left_on = "director_id", right_on = "id")

# %%
data.head(2)
# Out:
#     id_x     budget  popularity     revenue    title  vote_average  \
# 0  43597  237000000         150  2787965087   Avatar           7.2
# 1  43622  200000000         100  1845034188  Titanic           7.5
#
#    vote_count  director_id  year month       day  director_name  id_y gender
# 0       11800         4762  2009   Dec  Thursday  James Cameron  4762   Male
# 1        7562         4762  1997   Nov   Tuesday  James Cameron  4762   Male

# %%
data.drop(["director_id", "id_y"], axis = 1, inplace = True)

# %%
data.head(2)
# Out:
#     id_x     budget  popularity     revenue    title  vote_average  \
# 0  43597  237000000         150  2787965087   Avatar           7.2
# 1  43622  200000000         100  1845034188  Titanic           7.5
#
#    vote_count  year month       day  director_name gender
# 0       11800  2009   Dec  Thursday  James Cameron   Male
# 1        7562  1997   Nov   Tuesday  James Cameron   Male

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_x           1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   year           1465 non-null   int64
#  8   month          1465 non-null   object
#  9   day            1465 non-null   object
#  10  director_name  1465 non-null   object
#  11  gender         1341 non-null   object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 148.8+ KB

# %%
data.describe()
# Out:
#                id_x        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count         year
# count   1465.000000  1465.000000
# mean    1146.396587  2002.615017
# std     1578.077438     8.680141
# min        1.000000  1976.000000
# 25%      216.000000  1998.000000
# 50%      571.000000  2004.000000
# 75%     1387.000000  2009.000000
# ...

# %%
data.describe(include = object)
# Out:
#          title month     day     director_name gender
# count     1465  1465    1465              1465   1341
# unique    1465    12       7               199      2
# top     Avatar   Dec  Friday  Steven Spielberg   Male
# freq         1   193     654                26   1309

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue                       title  \
# 0  43597  237000000         150  2787965087                      Avatar
# 1  43622  200000000         100  1845034188                     Titanic
# 2  43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3  43879  115000000          38   378882411                   True Lies
# 4  44184   70000000          24    90000098                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
data["revenue"] = (data["revenue"]/1000000).round(2)

# %%
data.head()
# Out:
#     id_x     budget  popularity  revenue                       title  \
# 0  43597  237000000         150  2787.97                      Avatar
# 1  43622  200000000         100  1845.03                     Titanic
# 2  43876  100000000         101   520.00  Terminator 2: Judgment Day
# 3  43879  115000000          38   378.88                   True Lies
# 4  44184   70000000          24    90.00                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
# HW - budget(M)

# %%
# select * from movies where vote_avg > 7

# %%
data["vote_average"] > 7
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: vote_average, Length: 1465, dtype: bool

# %%
data[ data["vote_average"] > 7 ]
# Out:
#        id_x     budget  popularity  revenue                       title  \
# 0     43597  237000000         150  2787.97                      Avatar
# 1     43622  200000000         100  1845.03                     Titanic
# 2     43876  100000000         101   520.00  Terminator 2: Judgment Day
# 4     44184   70000000          24    90.00                   The Abyss
# 5     46000   18500000          67   183.32                      Aliens
# ...     ...        ...         ...      ...                         ...
# 1424  47488    4000000          11    35.56       Bowling for Columbine
# 1426  48310     160000           3     6.71                  Roger & Me
# 1433  46168   11500000          15    23.24      The Remains of the Day
# 1438  47597          0          11     0.00                     Maurice
# 1441  47232    5000000          35     8.20               The Machinist
#
#       vote_average  vote_count  year month        day  director_name gender
# ...

# %%
data.loc[ data["vote_average"] > 7 ]
# Out:
#        id_x     budget  popularity  revenue                       title  \
# 0     43597  237000000         150  2787.97                      Avatar
# 1     43622  200000000         100  1845.03                     Titanic
# 2     43876  100000000         101   520.00  Terminator 2: Judgment Day
# 4     44184   70000000          24    90.00                   The Abyss
# 5     46000   18500000          67   183.32                      Aliens
# ...     ...        ...         ...      ...                         ...
# 1424  47488    4000000          11    35.56       Bowling for Columbine
# 1426  48310     160000           3     6.71                  Roger & Me
# 1433  46168   11500000          15    23.24      The Remains of the Day
# 1438  47597          0          11     0.00                     Maurice
# 1441  47232    5000000          35     8.20               The Machinist
#
#       vote_average  vote_count  year month        day  director_name gender
# ...

# %%
data.loc[ data["vote_average"] > 7 , ["title", "director_name"]]
# Out:
#                            title  director_name
# 0                         Avatar  James Cameron
# 1                        Titanic  James Cameron
# 2     Terminator 2: Judgment Day  James Cameron
# 4                      The Abyss  James Cameron
# 5                         Aliens  James Cameron
# ...                          ...            ...
# 1424       Bowling for Columbine  Michael Moore
# 1426                  Roger & Me  Michael Moore
# 1433      The Remains of the Day    James Ivory
# 1438                     Maurice    James Ivory
# 1441               The Machinist  Brad Anderson
#
# [301 rows x 2 columns]

# %%
data.loc[ (data["vote_average"] > 7) & (data["year"] >= 2015) ]
# Out:
#       id_x     budget  popularity  revenue                    title  \
# 93   43867  108000000         167   630.16              The Martian
# 166  43641  190000000         102  1506.25                Furious 7
# 201  44784   40000000          48   165.48          Bridge of Spies
# 361  43724  150000000         434   378.86       Mad Max: Fury Road
# 465  43773  135000000         100   532.95             The Revenant
# 512  44128   75000000          48   108.15  The Man from U.N.C.L.E.
# 639  45301   28000000          57   133.35            The Big Short
# 649  44281   44000000          68   155.76        The Hateful Eight
# 766  44770   35000000          53   194.56               The Intern
# 818  47181    5000000          22    24.80                     Race
# 853  45293   28000000          61   201.63   Straight Outta Compton
# 861  45194   30000000          65    91.71                 Southpaw
#
#      vote_average  vote_count  year month        day  \
# ...

# %%
# | --> or
# & --> and

# %%
data[ (data["day"] == "Friday") | (data["day"] == "Saturday")]
# Out:
#        id_x     budget  popularity  revenue  \
# 5     46000   18500000          67   183.32
# 6     47036    6400000          74    78.37
# 7     43598  300000000         139   961.00
# 16    44041   80000000          49   181.00
# 17    44154   72000000          32    96.89
# ...     ...        ...         ...      ...
# 1455  46574   10000000          33   163.88
# 1457  46827          0           5     0.19
# 1458  47152    4000000          42   152.93
# 1462  47524    3000000           5     0.00
# 1464  48229     250000           1     4.19
#
#                                          title  vote_average  vote_count  \
# 5                                       Aliens           7.7        3220
# 6                               The Terminator           7.3        4128
# 7     Pirates of the Caribbean: At World's End           6.9        4500
# 16                           Road to Perdition           7.3        1077
# ...

# %%
data.sort_values(["popularity"], ascending = False).head(5)
# Out:
#       id_x     budget  popularity  revenue  \
# 23   43692  165000000         724   675.12
# 361  43724  150000000         434   378.86
# 11   43796  140000000         271   655.01
# 315  43797  125000000         206   752.10
# 22   43662  185000000         187  1004.56
#
#                                                  title  vote_average  \
# 23                                        Interstellar           8.1
# 361                                 Mad Max: Fury Road           7.2
# 11   Pirates of the Caribbean: The Curse of the Bla...           7.5
# 315              The Hunger Games: Mockingjay - Part 1           6.6
# 22                                     The Dark Knight           8.2
#
#      vote_count  year month        day      director_name gender
# 23        10867  2014   Nov  Wednesday  Christopher Nolan   Male
# 361        9427  2015   May  Wednesday      George Miller   Male
# 11         6985  2003   Jul  Wednesday     Gore Verbinski   Male
# ...

# %%
data.loc[data["director_name"] == "Christopher Nolan", ["title"]]
# Out:
#                     title
# 21  The Dark Knight Rises
# 22        The Dark Knight
# 23           Interstellar
# 24              Inception
# 25          Batman Begins
# 26               Insomnia
# 27           The Prestige
# 28                Memento

# %%
#Male --> 0
#Otherwise --> 1

# %%
def encode(data):
  if data == "Male":
    return 0
  else:
    return 1

# %%
data.head()
# Out:
#     id_x     budget  popularity  revenue                       title  \
# 0  43597  237000000         150  2787.97                      Avatar
# 1  43622  200000000         100  1845.03                     Titanic
# 2  43876  100000000         101   520.00  Terminator 2: Judgment Day
# 3  43879  115000000          38   378.88                   True Lies
# 4  44184   70000000          24    90.00                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
data["gender"] = data["gender"].apply(encode)

# %%
data.head()
# Out:
#     id_x     budget  popularity  revenue                       title  \
# 0  43597  237000000         150  2787.97                      Avatar
# 1  43622  200000000         100  1845.03                     Titanic
# 2  43876  100000000         101   520.00  Terminator 2: Judgment Day
# 3  43879  115000000          38   378.88                   True Lies
# 4  44184   70000000          24    90.00                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name  gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron       0
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron       0
# 2           7.7        4185  1991   Jul     Monday  James Cameron       0
# 3           6.8        1116  1994   Jul   Thursday  James Cameron       0
# 4           7.1         808  1989   Aug  Wednesday  James Cameron       0

# %%
#we will cover more examples of apply in next lec
